# %%
# %load_ext autoreload
# %autoreload 2

import sys
import math
import pickle 
import joblib
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from random import sample

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

sys.path.append('../')

from src.training.bankmarketing import *
from src.explainers import *
from src.timelimit import *
from src.explainers import *

pd.set_option('display.max_columns', 500)

import tensorflow as tf

# %% [markdown]
# # Train on full data

# %%
# %%capture --no-display
bm = BankMarketingModel()
bm.train_model()
bm.train_separate_model()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4[LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4[LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4[LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4[LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=6, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.7s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.7s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.7s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.7s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.8s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=8, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.8s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=0.4, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4
# [CV] END lgbmclassifier__feature_fraction=0.4, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.6s
# ...
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.8s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.8s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=1; total time=   0.2s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.8; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=1; total time=   0.7s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=0.4; total time=   0.7s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=10, lgbmclassifier__num_leaves=144, lgbmclassifier__subsample=1; total time=   0.6s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.4; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=8, lgbmclassifier__subsample=0.8; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.4; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=0.8; total time=   0.3s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=16, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=32, lgbmclassifier__subsample=0.4; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.4; total time=   0.5s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=0.8; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=64, lgbmclassifier__subsample=1; total time=   0.4s
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [CV] END lgbmclassifier__feature_fraction=1, lgbmclassifier__is_unbalance=True, lgbmclassifier__learning_rate=0.2, lgbmclassifier__max_depth=12, lgbmclassifier__num_leaves=96, lgbmclassifier__subsample=0.4; total time=   0.5s

# %%
bm.print_metrics()
# Out:
#  ROC AUC train :  0.7484875572359795
#  ROC AUC val :  0.7319015961177032
#  ROC AUC test :  0.7480720331356588
#
# Precision test :  0.4749568221070812
# Recall test :  0.5795574288724974
# F1 score test :  0.5220692928334124
# Predicted     0    1
# Actual
# 0          6681  608
# 1           399  550

# %% [markdown]
# # Dataset

# %%
bm.data.shape, bm.data.y.mean()

# %%
bm.names

# %%
bm.save_pipe(6) #6 is full data

# %%
bm.data.sample(5).to_excel(
    '/Users/kseniia/OneDrive/MSDS/Thesis/data/results/bm_sample.xlsx')

# %%
plt.subplots(figsize=(15, 10))
sns.heatmap(bm.data.corr());
# plt.title('Correlations between features in a Bank Marketing Dataset');

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=bm.data, palette="Set3", bw=.2, linewidth=.5);

# %%
names = [
 'pdays',
 'emp.var.rate',
 'cons.price.idx',
 'cons.conf.idx',
 'euribor3m',
 'nr.employed',
 'age',
 'campaign',
 ]
fig, ax = plt.subplots(1, len(names), figsize=(15,5))
for i, s in enumerate(names):
    df = bm.data
    sns.violinplot(data=df, x=s, bw=.2, linewidth=.5, hue='y',
                   ax=ax[i], orient='v');

# %%
names = ['job',
 'marital',
 'education',
 'housing',
 'loan',
 'contact',
 'poutcome',
 'month',
 'day_of_week',
 'previous',
 'default'
 ]
fig, ax = plt.subplots(len(names), 1, figsize=(15,25))
for i, s in enumerate(names):
    df = bm.data
    sns.countplot(data=df, x=s, hue='y', ax=ax[i]);

# %%
bm.data.columns

# %% [markdown]
# # DiCE Report

# %% [markdown]
# ## Generate counterfactuals for all data using only 2 changeable features, without custom range

# %%
features_to_vary = ['campaign', 'contact']
features_to_vary_sep = ['campaign', 'contact_cellular',
                        'contact_telephone']

# %%
dice = DiCeReport(bm, desired_class=1, 
                  features_to_vary=features_to_vary, custom_range=False)
dice.create_explainer(method='random',
                     cont_feats=bm.num_cols+bm.log_cols
                     )
# Out:
# None

# %%
# dice.get_cf(108, printout=True)

# %%
# %%capture --no-display
dice.evaluate_dataset(n=1, save=True, name='bm_dice_cf_2ft_2000')
# Out:
#   0%|          | 0/7080 [00:00<?, ?it/s]

# %%
 dice.cfs.keys()
# Out:
# dict_keys([1502, 3462, 13, 7189, 6281, 5426, 3274, 7504, 464, 1254, 2224, 2976, 588, 5452, 1788, 932, 4336, 6918, 6377, 5705, 206, 6520])

# %%
dice.print_metrics()
# Out:
# 85.94% of instances of undesired class in the dataset
# 7080 instances of undesired class analyzed
# 0.31% of successfull explanations, 22 instances
# 0.65% of programming package errors
# 99.04% of cases, where no CFs could be found by DiCE
# 0.13% of additional potential successes (model quality adjusted)
# 9 additional potential successes (model quality adjusted)
# 22 instances with recommended actions (extrapolated to the whole dataset)
# 9 additional successes in a test set  (model quality adjusted)
#
# In 100.0% cases 1 features were changes

# %%
dice.plot_diffs()

# %%
# dice.plot_diffs(5,4, ['emp.var.rate', 'euribor3m', 'campaign'])
# dice.plot_diffs(5,4, ['cons.price.idx'])
# dice.plot_diffs(5,4, ['cons.conf.idx'])

# %% [markdown]
# ## Generate counterfactuals for all data using only 2 changeable features with custom range

# %%
dice2 = DiCeReport(bm, desired_class=1, 
                  features_to_vary=features_to_vary, custom_range=True)
dice2.create_explainer(method='random',
                     cont_feats=bm.num_cols+bm.log_cols
                     )
# Out:
# {'campaign': [1.0, 7.0], 'contact': ['cellular', 'telephone']}

# %%
# %%capture --no-display
dice2.evaluate_dataset(n=1, save=True, name='bm_dice_cf_2ft_all')
# Out:
#   0%|          | 0/7080 [00:00<?, ?it/s]

# %%
dice2.cfs.keys()
# Out:
# dict_keys([1502, 3462, 13, 7189, 6281, 5426, 3274, 464, 1254, 2224, 2976, 588, 5452, 1788, 932, 4336, 6918, 6377, 5705, 206, 6520])

# %%
dice2.print_metrics()
# Out:
# 85.94% of instances of undesired class in the dataset
# 7080 instances of undesired class analyzed
# 0.3% of successfull explanations, 21 instances
# 0.66% of programming package errors
# 99.04% of cases, where no CFs could be found by DiCE
# 0.11% of additional potential successes (model quality adjusted)
# 8 additional potential successes (model quality adjusted)
# 21 instances with recommended actions (extrapolated to the whole dataset)
# 8 additional successes in a test set  (model quality adjusted)
#
# In 100.0% cases 1 features were changes

# %%
dice2.plot_diffs()

# %% [markdown]
# ### Generate counterfactuals for all data using 8 changeable features with custom range

# %%
# [8,9,10,12,16,17,18,19]
features_to_vary = ['contact', 'month', 'campaign', 'emp.var.rate',
                    'cons.price.idx', 'cons.conf.idx', 'euribor3m',
                    'day_of_week'
                    ]
features_to_vary_sep = [ 'contact', 'campaign', 'emp.var.rate',
                     'cons.price.idx', 'cons.conf.idx', 'euribor3m',
                     'month_apr', 'month_aug', 'month_dec',
                     'month_jul', 'month_jun', 'month_mar',
                     'month_may', 'month_nov', 'month_oct', 'month_sep',
                     'day_of_week_fri', 'day_of_week_mon',
                     'day_of_week_thu', 'day_of_week_tue',
                     'day_of_week_wed'  ]

# %%
dice3 = DiCeReport(bm, desired_class=1, 
                  features_to_vary=features_to_vary, custom_range=False)
dice3.create_explainer(method='random', cont_feats=bm.num_cols+bm.log_cols)
# Out:
# None

# %%
# %%capture --no-display
dice3.evaluate_dataset(n=1, save=True, name='bm_dice_cf_8ft_all')
# Out:
#   0%|          | 0/7080 [00:00<?, ?it/s]

# %%
dice3.cfs.keys()
# Out:
# dict_keys([3098, 1468, 3766, 6186, 470, 710, 7826, 5095, 925, 3495, 5535, 574, 4831, 2070, 368, 842, 4136, 3979, 684, 2314, 890, 5242, 4050, 585, 7881, 5371, 1210, 2153, 5990, 5960, 5536, 608, 5481, 483, 2135, 5295, 8186, 1409, 1152, 5420, 2944, 5326, 7771, 6483, 1745, 1010, 5524, 5423, 6068, 1823, 3561, 956, 6770, 616, 5362, 5873, 1989, 4724, 5057, 4080, 3003, 4440, 8200, 4323, 3459, 2863, 2388, 7566, 1737, 6642, 7421, 2346, 5455, 2869, 5001, 4712, 3277, 6936, 4282, 717, 1155, 4872, 8218, 3266, 4657, 4020, 384, 6353, 759, 7268, 5308, 7512, 3000, 6603, 3350, 5644, 4727, 5508, 7591, 4354, 674, 920, 2591, 4519, 6620, 6316, 635, 598, 6952, 2958, 6149, 6475, 7833, 4254, 6813, 6357, 3318, 219, 4407, 3396, 1628, 5794, 1147, 4699, 583, 7304, 2749, 1262, 7023, 2380, 3795, 3732, 4725, 788, 4285, 3831, 5226, 2659, 1335, 7808, 4106, 2665, 6716, 3950, 3433, 6491, 3636, 1469, 810, 1472, 2236, 6259, 2248, 4617, 7923, 5592, 2527, 2699, 39, 1421, 3987, 5083, 5785, 5378, 3047, 1226, 6562, 4908, 5859, 6225, 6427, 7037, 536, 4357, 6468, 7599, 5318, 3744, 3796, 3804, 3759, 1014, 4585, 3816, 611, 1845, 659, 2016, 1574, 1072, 3247, 5704, 521, 3, 5383, 8035, 5103, 996, 3477, 5820, 246, 5823, 3595, 1446, 6028, 2424, 3321, 5717, 3483, 1202, 1130, 4648, 4444, 4575, 4607, 2979, 839, 1408, 1003, 3270, 7041, 4559, 7901, 1567, 224, 1982, 5027, 6559, 7210, 5026, 6105, 892, 6613, 4935, 3504, 1619, 3399, 7341, 2150, 5065, 5150, 7413, 4786, 3153, 6044, 2152, 5815, 7726, 7212, 1886, 7673, 2304, 8113, 3818, 7038, 7648, 2186, 4927, 4690, 6951, 282, 268, 4501, 
# %%
dice3.print_metrics()
# Out:
# 85.94% of instances of undesired class in the dataset
# 7080 instances of undesired class analyzed
# 84.11% of successfull explanations, 5955 instances
# 15.88% of programming package errors
# 0.01% of cases, where no CFs could be found by DiCE
# 35.95% of additional potential successes (model quality adjusted)
# 2545 additional potential successes (model quality adjusted)
# 5955 instances with recommended actions (extrapolated to the whole dataset)
# 2545 additional successes in a test set  (model quality adjusted)
#
# In 62.89% cases 2 features were changes
# In 23.79% cases 3 features were changes
# In 10.85% cases 1 features were changes
# In 2.35% cases 4 features were changes
# In 0.1% cases 5 features were changes
# In 0.01% cases 6 features were changes

# %%
dice3.plot_diffs(16,8)

# %% [markdown]
# ### Generate counterfactuals for all data using 8 changeable features without custom range

# %%
dice4 = DiCeReport(bm, desired_class=1, 
                  features_to_vary=features_to_vary, custom_range=True)
dice4.create_explainer(method='random', cont_feats=bm.num_cols+bm.log_cols)
# Out:
# {'contact': ['cellular', 'telephone'], 'month': ['jul', 'jun', 'may', 'apr', 'aug', 'dec', 'nov', 'oct', 'mar', 'sep'], 'campaign': [1.0, 7.0], 'emp.var.rate': [-2.9, 1.4], 'cons.price.idx': [92.713, 94.465], 'cons.conf.idx': [-47.1, -33.6], 'euribor3m': [0.793, 4.966], 'day_of_week': ['thu', 'wed', 'fri', 'mon', 'tue']}

# %%
# %%capture --no-display
dice4.evaluate_dataset(n=1, save=True, name='bm_dice_cf_8ft_all')
# Out:
#   0%|          | 0/7080 [00:00<?, ?it/s]

# %%
dice4.cfs.keys()
# Out:
# dict_keys([3098, 1468, 3766, 6186, 470, 710, 7826, 5095, 925, 3495, 5535, 574, 4831, 2070, 368, 842, 4136, 3979, 684, 2314, 890, 5242, 4050, 585, 7881, 5371, 1210, 2153, 5990, 5960, 5536, 608, 5481, 483, 2135, 5295, 8186, 1409, 1152, 5420, 2944, 5326, 7771, 6483, 1745, 1010, 5524, 5423, 6068, 1823, 3561, 956, 6770, 616, 5362, 5873, 1989, 4724, 5057, 4080, 3003, 4440, 8200, 4323, 3459, 2863, 2388, 7566, 1737, 6642, 7421, 2346, 5455, 2869, 5001, 4712, 3277, 6936, 4282, 717, 1155, 4872, 8218, 3266, 4657, 4020, 384, 6353, 759, 7268, 5308, 7512, 3000, 6603, 3350, 5644, 4727, 5508, 7591, 4354, 674, 920, 2591, 4519, 6620, 6316, 635, 598, 6952, 2958, 6149, 6475, 7833, 4254, 6813, 6357, 3318, 219, 4407, 3396, 1628, 5794, 1147, 4699, 583, 7304, 
 7623, 2519, 497, 1947, 2980, 5973, 2911, 5051, 7223, 1988, 2770, 4255, 4760, 6387, 1720, 8078, 7602, 2406, 362, 151, 180, 6970, 4814, 8213, 1836, 4894, 2363, 4268, 1040, 6257, 4123, 6240, 8143, 5193, 3751, 4825, 2937, 6535, 6721, 6040, 3857, 3323, 539, 1266, 7777, 693, 5941, 7046, 4108, 1587, 549, 827, 6327, 3640, 4817, 8022, 5684, 2329, 7799, 2800, 440, 4384, 1794, 1532, 7557, 4258, 35, 2531, 7949, 3146, 5202, 2352, 2957, 2104, 7837, 1768, 11, 3207, 3646, 820, 4524, 2669, 7899, 6236, 1941, 2385, 4806, 7384, 891, 2539, 881, 1406, 406, 3758, 8077, 2862, 2904, 5982, 2243, 7452, 5559, 5035, 1508, 6250, 5662, 3720, 3117, 6853, 4705, 1456, 2719, 6884, 5871, 6108, 1413, 426, 4883, 8204, 4096, 6978, 6665, 1359, 4987, 7162, 4802, 5397, 158, 6524, 5545, 6762, 6493, 6586, 7914, 2217, 832, 309, 8193, 3451, 1028, 5312, 501, 5963, 183, 5055, 6470, 2353, 4660, 2535, 33, 4361, 7115, 5089, 904, 5007, 645, 7093, 7006, 2422, 730, 7589, 6935, 7194, 7925, 8039, 8005, 6175, 4394, 4703, 3656, 4563, 6501, 2748, 455, 5853, 6104, 1916, 5693, 1436, 3171, 2444, 6192, 7067, 5392, 13 ...

# %%
dice4.print_metrics()
# Out:
# 85.94% of instances of undesired class in the dataset
# 7080 instances of undesired class analyzed
# 83.95% of successfull explanations, 5944 instances
# 16.02% of programming package errors
# 0.03% of cases, where no CFs could be found by DiCE
# 35.89% of additional potential successes (model quality adjusted)
# 2541 additional potential successes (model quality adjusted)
# 5944 instances with recommended actions (extrapolated to the whole dataset)
# 2541 additional successes in a test set  (model quality adjusted)
#
# In 54.08% cases 2 features were changes
# In 31.69% cases 3 features were changes
# In 7.95% cases 1 features were changes
# In 5.28% cases 4 features were changes
# In 1.0% cases 5 features were changes
# In 0.0% cases 6 features were changes

# %%
dice4.plot_diffs(16,8)

# %% [markdown]
# # LimeReport

# %%
lime = LimeReport(bm, desired_class=1, 
                  features_to_vary=features_to_vary_sep, 
                  use_sep_model=True)
lime.create_explainer()
lime.evaluate_dataset(dice.cfs)
lime.plot_coefs()

# %% [markdown]
# # Shap Report

# %%
shv = ShapReport(bm, desired_class=1, features_to_vary=features_to_vary_sep, 
                 use_sep_model=True)
shv.create_explainer()
shv.evaluate_dataset(dice.cfs)
shv.plot_coefs()

# %% [markdown]
# # Compare methods result

# %%
comp = Comparator(model=bm, dice=dice, sh=shv, use_sep_model=True)
comp.compare_dice_slime()

# %%
comp.compare_dice_shap()

# %%
comp.compare_lime_shap()

# %%
comp.dice.cfs.keys()

# %%
instance_id = 6890
comp.compare_instance(instance_id)

# %%
dice.get_cf(159, printout=True)
